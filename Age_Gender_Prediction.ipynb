# %% [markdown]
# <a href="https://colab.research.google.com/github/Hmzkhnswt/Age-Gender-predictor-Model/blob/main/Age_Gender_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### If you have to unzip file

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d jangedoo/utkface-new
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# utkface-new.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip = zipfile.ZipFile("/content/utkface-new.zip",'r')
zip.extractall("/content")
zip.close()

# %%
import numpy as np
import pandas as pd
import os
from keras.preprocessing.image import ImageDataGenerator

# %%
folder_path = '/content/utkface_aligned_cropped/UTKFace'

# %%
age = []
gender = []
img_path = []
for file in os.listdir(folder_path):
    age.append(int(file.split('_')[0]))
    gender.append(int(file.split('_')[1]))
    img_path.append(file)

# %%
len(age)
# Out:
# 23708

# %%
len(gender)
# Out:
# 23708

# %%
df = pd.DataFrame({'age' : age, 'gender' : gender, 'img' : img_path})
df.head()
# Out:
#    age  gender                                    img
# 0   60       0  60_0_0_20170104212943692.jpg.chip.jpg
# 1   21       1  21_1_3_20170119155647331.jpg.chip.jpg
# 2   30       0  30_0_4_20170117194418932.jpg.chip.jpg
# 3   60       1  60_1_2_20170116192433309.jpg.chip.jpg
# 4   56       0  56_0_0_20170104212131403.jpg.chip.jpg
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['gender'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_2, *['age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['gender'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_4, *['img'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_5, *[[['age', 'gender']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_6, *['age', 'img'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_7, *['gender', 'img'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_8, *['age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['gender'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_10, *['age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_11, *['gender'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_12, *['img'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_13, *[[['age', 'gender']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_14, *['age', 'img'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_15, *['gender', 'img'], **{'inner': 'stick'})
# chart

# %%
train_df = df.sample(frac=1, random_state=0).iloc[:20000]
test_df = df.sample(frac=1, random_state=0).iloc[20000:]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (20000, 3)
# (3708, 3)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_gen = train_datagen.flow_from_dataframe(
    train_df,
    directory=folder_path,
    x_col='img',
    y_col= ['age', 'gender'],
    target_size=(200,200),
    class_mode='multi_output'
)

test_gen = train_datagen.flow_from_dataframe(
    test_df,
    directory=folder_path,
    x_col='img',
    y_col= ['age', 'gender'],
    target_size=(200,200),
    class_mode='multi_output'
)
# Out:
# Found 20000 validated image filenames.
# Found 3708 validated image filenames.

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import *
from keras.models import Model

# %%
vggnet = VGG16(include_top=False, input_shape=(200,200,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
vggnet.trainable = False
output = vggnet.layers[-1].output

# %%
flatten = Flatten()(output)
dense1 = Dense(512, activation='relu')(flatten)
dense2 = Dense(512, activation='relu')(flatten)

dense3 = Dense(512, activation='relu')(dense1)
dense4 = Dense(512, activation='relu')(dense2)

output1 = Dense(1, activation='linear', name = 'age')(dense3)
output2 = Dense(1, activation='sigmoid', name = 'gender')(dense4)

# %%
model = Model(inputs = vggnet.inputs, outputs = [output1,output2])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 200, 200, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 200, 200, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 100, 100, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 100, 100, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 100, 100, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 50, 50, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 50, 50, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 50, 50, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 50, 50, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 25, 25, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 25, 25, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 25, 25, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 25, 25, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 12, 12, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 12, 12, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 12, 12, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 12, 12, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 6, 6, 512)    0           ['block5_conv3[0][0]']
#
#  flatten (Flatten)              (None, 18432)        0           ['block5_pool[0][0]']
#
#  dense (Dense)                  (None, 512)          9437696     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 512)          9437696     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 512)          262656      ['dense[0][0]']
#
#  dense_3 (Dense)                (None, 512)          262656      ['dense_1[0][0]']
#
#  age (Dense)                    (None, 1)            513         ['dense_2[0][0]']
#
#  gender (Dense)                 (None, 1)            513         ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 34,116,418
# Trainable params: 19,401,730
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %%
model.compile(loss={'age': 'mae', 'gender' : 'binary_crossentropy'}, optimizer='adam', metrics={'age': 'mae', 'gender': 'accuracy'}, loss_weights={'age': 1, 'gender': 99})

# %%
model.fit(train_gen, epochs=10, batch_size=32 ,validation_data=test_gen)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 318s 486ms/step - loss: 64.7910 - age_loss: 11.1437 - gender_loss: 0.5419 - age_mae: 11.1437 - gender_accuracy: 0.7307 - val_loss: 62.6750 - val_age_loss: 10.0610 - val_gender_loss: 0.5315 - val_age_mae: 10.0610 - val_gender_accuracy: 0.7673
# Epoch 2/10
# 625/625 [==============================] - 260s 416ms/step - loss: 55.2972 - age_loss: 9.5920 - gender_loss: 0.4617 - age_mae: 9.5920 - gender_accuracy: 0.7771 - val_loss: 55.4682 - val_age_loss: 9.7257 - val_gender_loss: 0.4620 - val_age_mae: 9.7257 - val_gender_accuracy: 0.7770
# Epoch 3/10
# 625/625 [==============================] - 260s 416ms/step - loss: 52.6555 - age_loss: 9.3008 - gender_loss: 0.4379 - age_mae: 9.3008 - gender_accuracy: 0.7926 - val_loss: 49.1359 - val_age_loss: 9.0787 - val_gender_loss: 0.4046 - val_age_mae: 9.0787 - val_gender_accuracy: 0.8204
# Epoch 4/10
# 625/625 [==============================] - 261s 418ms/step - loss: 50.9048 - age_loss: 8.9834 - gender_loss: 0.4234 - age_mae: 8.9834 - gender_accuracy: 0.7973 - val_loss: 52.2470 - val_age_loss: 9.2462 - val_gender_loss: 0.4344 - val_age_mae: 9.2462 - val_gender_accuracy: 0.7961
# Epoch 5/10
# 625/625 [==============================] - 254s 406ms/step - loss: 50.3118 - age_loss: 8.9319 - gender_loss: 0.4180 - age_mae: 8.9319 - gender_accuracy: 0.8013 - val_loss: 47.8879 - val_age_loss: 8.8018 - val_gender_loss: 0.3948 - val_age_mae: 8.8018 - val_gender_accuracy: 0.8204
# Epoch 6/10
# 625/625 [==============================] - 252s 404ms/step - loss: 48.9414 - age_loss: 8.6380 - gender_loss: 0.4071 - age_mae: 8.6380 - gender_accuracy: 0.8063 - val_loss: 51.7986 - val_age_loss: 9.5469 - val_gender_loss: 0.4268 - val_age_mae: 9.5469 - val_gender_accuracy: 0.7988
# Epoch 7/10
# 625/625 [==============================] - 253s 404ms/step - loss: 48.2442 - age_loss: 8.6615 - gender_loss: 0.3998 - age_mae: 8.6615 - gender_accuracy: 0.8102 - val_loss: 51.0739 - val_age_loss: 8.5736 - val_gender_loss: 0.4293 - val_age_mae: 8.5736 - val_gender_accuracy: 0.7940
# Epoch 8/10
# 625/625 [==============================] - 250s 401ms/step - loss: 48.3701 - age_loss: 8.5177 - gender_loss: 0.4025 - age_mae: 8.5177 - gender_accuracy: 0.8109 - val_loss: 51.2680 - val_age_loss: 9.5328 - val_gender_loss: 0.4216 - val_age_mae: 9.5328 - val_gender_accuracy: 0.8002
# Epoch 9/10
# 625/625 [==============================] - 249s 398ms/step - loss: 47.4537 - age_loss: 8.4606 - gender_loss: 0.3939 - age_mae: 8.4606 - gender_accuracy: 0.8159 - val_loss: 46.0897 - val_age_loss: 8.8402 - val_gender_loss: 0.3763 - val_age_mae: 8.8402 - val_gender_accuracy: 0.8250
# Epoch 10/10
# 625/625 [==============================] - 252s 403ms/step - loss: 46.8835 - age_loss: 8.4297 - gender_loss: 0.3884 - age_mae: 8.4297 - gender_accuracy: 0.8213 - val_loss: 45.5417 - val_age_loss: 8.3839 - val_gender_loss: 0.3753 - val_age_mae: 8.3839 - val_gender_accuracy: 0.8355

# %%
import pickle
with open("age_gender.pkl", "wb") as file1:
    pickle.dump(model, file1)
